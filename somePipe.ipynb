# %%
import os
from SomeUsefulFunc import parseParams, getSamples, getResultsList, getPlot

# %%
for num in (10, 100, 500):
    for dir in os.listdir("./LOGS/"):
        if f'1dim-{num}-' in dir:
            dim, sample_size, iter_number, direction_name, file_name = parseParams(dir)
            Samples = getSamples(file_name)
            ResultsForMaxList, ResultsForSumList = getResultsList(direction_name)
            getPlot(ResultsForMaxList, dim, sample_size, iter_number, 'max')

# %%
for num in (10, 100, 500):
    for dir in os.listdir("./LOGS/"):
        if f'1dim-{num}-' in dir:
            dim, sample_size, iter_number, direction_name, file_name = parseParams(dir)
            Samples = getSamples(file_name)
            ResultsForMaxList, ResultsForSumList = getResultsList(direction_name)
            getPlot(ResultsForSumList, dim, sample_size, iter_number, 'sum')

# %%
for num in (10, 100, 500):
    for dir in os.listdir("./LOGS/"):
        if f'2dim-{num}-' in dir:
            dim, sample_size, iter_number, direction_name, file_name = parseParams(dir)
            Samples = getSamples(file_name)
            ResultsForMaxList, ResultsForSumList = getResultsList(direction_name)
            getPlot(ResultsForMaxList, dim, sample_size, iter_number, 'max')

# %%
for dir in os.listdir("./LOGS/"):
    if '2dim' in dir:
        dim, sample_size, iter_number, direction_name, file_name = parseParams(dir)
        Samples = getSamples(file_name)
        ResultsForMaxList, ResultsForSumList = getResultsList(direction_name)
        getPlot(ResultsForMaxList, dim, sample_size, iter_number, 'max')

# %%
for dir in os.listdir("./LOGS/"):
    dim, sample_size, iter_number, direction_name, file_name = parseParams(dir)
    Samples = getSamples(file_name)
    ResultsForMaxList, ResultsForSumList = getResultsList(direction_name)
    getPlot(ResultsForSumList, dim, sample_size, iter_number, 'sum')
